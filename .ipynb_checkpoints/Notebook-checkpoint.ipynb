# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',100)

# %%
df = pd.read_csv("training_data.csv")
df.shape[0]
# Out:
# 91589

# %%
df.head()
# Out:
#    Unnamed: 0  encounter_id  patient_nbr             race  gender      age  \
# 0       83148     259912530     88114716        Caucasian  Female  [60-70)
# 1        8067      37094196       604017        Caucasian  Female  [60-70)
# 2       19623      69819834      3401055  AfricanAmerican  Female  [40-50)
# 3       77236     234245010     71780013        Caucasian    Male  [70-80)
# 4       55677     160693860     82716489        Caucasian  Female  [80-90)
#
#   weight  admission_type_id  discharge_disposition_id  admission_source_id  \
# 0      ?                  1                         6                    7
# 1      ?                  1                         1                    7
# 2      ?                  1                         6                    7
# 3      ?                  2                         6                    1
# 4      ?                  6                         3                    7
#
#    time_in_hospital payer_code       medical_specialty  num_lab_procedures  \
# 0                 1         MC                       ?                  34
# 1                 2          ?  Family/GeneralPractice                  39
# 2                 5          ?  Family/GeneralPractice                  63
# 3                 2         MC                       ?                  39
# 4                12          ?        InternalMedicine                  71
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0               10                  6                 0
# 1               0               11                  0                 0
# 2               1               11                  1                 0
# 3               0               22                  3                 0
# 4               1               15                  0                 0
#
#    number_inpatient diag_1 diag_2 diag_3  number_diagnoses max_glu_serum  \
# 0                 0    490    427    571                 9           NaN
# 1                 0    428    250    305                 4           NaN
# 2                11    535    285    585                 5           NaN
# 3                 2    482    428    585                 9           NaN
# 4                 0    733    584    682                 6          Norm
#
#   A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0       NaN        No          No          No             No          No
# 1       NaN    Steady          No          No             No          No
# 2       NaN        No          No          No             No          No
# 3       NaN        No          No          No             No          No
# 4       NaN        No          No          No             No          No
#
#   acetohexamide glipizide glyburide tolbutamide pioglitazone rosiglitazone  \
# 0            No        No        No          No           No            No
# 1            No        Up        No          No           No            No
# 2            No        No        No          No           No            No
# 3            No        No        No          No           No            No
# 4            No        No        No          No           No            No
#
#   acarbose miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0       No       No           No         No      No          No      Up
# 1       No       No           No         No      No          No      No
# 2       No       No           No         No      No          No      No
# 3       No       No           No         No      No          No    Down
# 4       No       No           No         No      No          No      No
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed readmitted
# 0                      No                     No     Ch         Yes         NO
# 1                      No                     No     Ch         Yes         NO
# 2                      No                     No     No          No        >30
# 3                      No                     No     Ch         Yes         NO
# 4                      No                     No     No          No        >30

# %%
df.describe()
# Out:
#           Unnamed: 0  encounter_id   patient_nbr  admission_type_id  \
# count   91589.000000  9.158900e+04  9.158900e+04       91589.000000
# mean    50823.527378  1.649819e+08  5.430075e+07           2.018845
# std     29378.923310  1.025752e+08  3.869786e+07           1.442623
# min         0.000000  1.252200e+04  1.350000e+02           1.000000
# 25%     25393.000000  8.491298e+07  2.340412e+07           1.000000
# 50%     50801.000000  1.522590e+08  4.543573e+07           1.000000
# 75%     76285.000000  2.301097e+08  8.754940e+07           3.000000
# max    101765.000000  4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count              91589.000000         91589.000000      91589.000000
# mean                   3.707192             5.764906          4.395877
# std                    5.271584             4.058986          2.986149
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    3.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count        91589.000000    91589.000000     91589.000000       91589.000000
# mean            43.141010        1.335368        16.018878           0.370972
# std             19.673918        1.702572         8.128192           1.273504
# min              1.000000        0.000000         1.000000           0.000000
# 25%             32.000000        0.000000        10.000000           0.000000
# 50%             44.000000        1.000000        15.000000           0.000000
# 75%             57.000000        2.000000        20.000000           0.000000
# max            132.000000        6.000000        81.000000          42.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count      91589.000000      91589.000000      91589.000000
# mean           0.197939          0.634727          7.423337
# std            0.941679          1.261203          1.934991
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          6.000000
# 50%            0.000000          0.000000          8.000000
# 75%            0.000000          1.000000          9.000000
# max           76.000000         21.000000         16.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# encounter_id                    0
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# weight                          0
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                      0
# medical_specialty               0
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                          0
# diag_2                          0
# diag_3                          0
# number_diagnoses                0
# max_glu_serum               86780
# A1Cresult                   76267
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
missing_cols = ['race', 'weight', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'gender']

column_to_missing = {}
for col in missing_cols:
    if col != 'gender':
        column_to_missing[col] = '?'
    else:
        column_to_missing[col] = 'Unknown/Invalid'

print(column_to_missing)
# Out:
# {'race': '?', 'weight': '?', 'payer_code': '?', 'medical_specialty': '?', 'diag_1': '?', 'diag_2': '?', 'diag_3': '?', 'gender': 'Unknown/Invalid'}

# %%
df_1 = df.copy()
for col, miss_val in column_to_missing.items():
    df_1[col] = df[col].replace(miss_val, np.nan)

df_1.isnull().sum()
# Out:
# Unnamed: 0                      0
# encounter_id                    0
# patient_nbr                     0
# race                         2044
# gender                          2
# age                             0
# weight                      88727
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  36237
# medical_specialty           44911
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         19
# diag_2                        332
# diag_3                       1292
# number_diagnoses                0
# max_glu_serum               86780
# A1Cresult                   76267
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64
