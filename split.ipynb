# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

seed = 1234
np.random.seed(seed)

# %%
pd_train.shape
# Out:
# (91589, 50)

# %%
pd_test.shape
# Out:
# (10177, 50)

# %%
mask = diabetes['readmitted'] == 'NO'
ratio = diabetes[mask]['readmitted'].count() / diabetes['readmitted'].count()
print("ratio: ", ratio)
# Out:
# ratio:  0.5391191557101586
